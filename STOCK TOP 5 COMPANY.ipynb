# %% [markdown]
# # STOCK TOP 5 COMPANY

# %%
import pandas as pd
import numpy as np
import datetime
import seaborn as sns
# %matplotlib inline
import datetime as dt
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ADSK=pd.read_csv("D:\\IBM_Data_Science\\Data_set\\Data_Kagle_Github\\data_stock\\ADSK_data.csv")
AMZN=pd.read_csv("D:\\IBM_Data_Science\\Data_set\\Data_Kagle_Github\\data_stock\\AMZN_data.csv")
ANSS=pd.read_csv("D:\\IBM_Data_Science\\Data_set\\Data_Kagle_Github\\data_stock\\ANSS_data.csv")
AAPL=pd.read_csv("D:\\IBM_Data_Science\\Data_set\\Data_Kagle_Github\\data_stock\\AAPL_data.csv")
AMG=pd.read_csv("D:\\IBM_Data_Science\\Data_set\\Data_Kagle_Github\\data_stock\\Mec_AMG_data.csv")

# %%
tickers=['ADSK',"AMZN","ANSS","AAPL","AMG"]

# %%
stocks_cp=pd.concat([ADSK,AMZN,ANSS,AAPL,AMG],axis=1,keys=tickers)

# %%
stocks_cp.head()
# Out:
#          ADSK                                                   AMZN          \
#          date   open   high    low  close   volume  Name        date    open
# 0  2013-02-08  38.79  39.00  38.69  38.89  1534449  ADSK  2013-02-08  261.40
# 1  2013-02-11  39.07  39.21  38.63  38.89  1368345  ADSK  2013-02-11  263.20
# 2  2013-02-12  38.91  39.24  38.80  38.91  1907926  ADSK  2013-02-12  259.19
# 3  2013-02-13  38.91  39.17  38.53  38.66  1708966  ADSK  2013-02-13  261.53
# 4  2013-02-14  38.54  38.77  38.22  38.67  2525540  ADSK  2013-02-14  267.37
#
#            ...     AAPL                          AMG                   \
#      high  ...    close     volume  Name        date    open     high
# 0  265.25  ...  67.8542  158168416  AAPL  2013-02-08  146.84  147.165
# 1  263.25  ...  68.5614  129029425  AAPL  2013-02-11  146.42  146.660
# 2  260.16  ...  66.8428  151829363  AAPL  2013-02-12  145.89  146.420
# 3  269.96  ...  66.7156  118721995  AAPL  2013-02-13  145.99  146.520
# ...

# %%
stocks_cp.tail()
# Out:
#             ADSK                                                       AMZN  \
#             date    open    high     low   close   volume  Name        date
# 1254  2018-02-01  114.72  117.70  114.08  115.57  1596444  ADSK  2018-02-01
# 1255  2018-02-02  114.12  115.14  111.60  111.64  1808333  ADSK  2018-02-02
# 1256  2018-02-05  110.60  116.15  109.18  109.18  2890782  ADSK  2018-02-05
# 1257  2018-02-06  106.49  112.65  104.61  112.62  3144823  ADSK  2018-02-06
# 1258  2018-02-07  111.77  113.56  110.51  110.54  1599666  ADSK  2018-02-07
#
#                         ...    AAPL                         AMG          \
#          open     high  ...   close    volume  Name        date    open
# 1254  1445.00  1459.88  ...  167.78  47230787  AAPL  2018-02-01  198.39
# 1255  1477.39  1498.00  ...  160.50  86593825  AAPL  2018-02-02  199.86
# 1256  1402.62  1458.98  ...  156.49  72738522  AAPL  2018-02-05  194.65
# 1257  1361.46  1443.99  ...  163.03  68243838  AAPL  2018-02-06  182.00
# ...

# %%
stocks_cp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 35 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   (ADSK, date)    1259 non-null   object
#  1   (ADSK, open)    1259 non-null   float64
#  2   (ADSK, high)    1259 non-null   float64
#  3   (ADSK, low)     1259 non-null   float64
#  4   (ADSK, close)   1259 non-null   float64
#  5   (ADSK, volume)  1259 non-null   int64
#  6   (ADSK, Name)    1259 non-null   object
#  7   (AMZN, date)    1259 non-null   object
#  8   (AMZN, open)    1259 non-null   float64
#  9   (AMZN, high)    1259 non-null   float64
#  10  (AMZN, low)     1259 non-null   float64
#  11  (AMZN, close)   1259 non-null   float64
#  12  (AMZN, volume)  1259 non-null   int64
#  13  (AMZN, Name)    1259 non-null   object
#  14  (ANSS, date)    1259 non-null   object
#  15  (ANSS, open)    1259 non-null   float64
#  16  (ANSS, high)    1259 non-null   float64
# ...

# %%
stocks_cp.columns.names=['Bank Ticker','Stock Info']

# %%
stocks_cp.head(5)
# Out:
# Bank Ticker        ADSK                                             \
# Stock Info         date   open   high    low  close   volume  Name
# 0            2013-02-08  38.79  39.00  38.69  38.89  1534449  ADSK
# 1            2013-02-11  39.07  39.21  38.63  38.89  1368345  ADSK
# 2            2013-02-12  38.91  39.24  38.80  38.91  1907926  ADSK
# 3            2013-02-13  38.91  39.17  38.53  38.66  1708966  ADSK
# 4            2013-02-14  38.54  38.77  38.22  38.67  2525540  ADSK
#
# Bank Ticker        AMZN                  ...     AAPL                   \
# Stock Info         date    open    high  ...    close     volume  Name
# 0            2013-02-08  261.40  265.25  ...  67.8542  158168416  AAPL
# 1            2013-02-11  263.20  263.25  ...  68.5614  129029425  AAPL
# 2            2013-02-12  259.19  260.16  ...  66.8428  151829363  AAPL
# 3            2013-02-13  261.53  269.96  ...  66.7156  118721995  AAPL
# ...

# %%
# Close max price
for tick in tickers:
    print(tick,stocks_cp[tick]['close'].max())
# Out:
# ADSK 130.24
# AMZN 1450.89
# ANSS 163.96
# AAPL 179.26
# AMG 228.02

# %%
# Close mean price
stocks_cp.xs(key='close',axis=1,level='Stock Info').mean()
# Out:
# Bank Ticker
# ADSK     64.194336
# AMZN    576.880041
# ANSS     93.600523
# AAPL    109.066698
# AMG     179.174662
# dtype: float64

# %%
# Close min price
min_price=stocks_cp.xs(key='close',axis=1,level='Stock Info').min()
min_price.head(5)
# Out:
# Bank Ticker
# ADSK     33.4800
# AMZN    248.2300
# ANSS     71.1700
# AAPL     55.7899
# AMG     117.8000
# dtype: float64

# %%
# Volume max price
stocks_cp.xs(key='volume',axis=1,level='Stock Info').max()
# Out:
# Bank Ticker
# ADSK     19486960
# AMZN     23856060
# ANSS     17613441
# AAPL    266833581
# AMG       8628523
# dtype: int64

# %%
# Volume mean price
stocks_cp.xs(key='volume',axis=1,level='Stock Info').mean()
# Out:
# Bank Ticker
# ADSK    2.482751e+06
# AMZN    3.730465e+06
# ANSS    4.391978e+05
# AAPL    5.404790e+07
# AMG     4.518571e+05
# dtype: float64

# %%
# Volumn min price
stocks_cp.xs(key='volume',axis=1,level='Stock Info').min()
# Out:
# Bank Ticker
# ADSK      355479
# AMZN     1092970
# ANSS       88425
# AAPL    11475922
# AMG        78029
# dtype: int64

# %%
# Open max price
stocks_cp.xs(key='open',axis=1,level='Stock Info').max()
# Out:
# Bank Ticker
# ADSK     130.76
# AMZN    1477.39
# ANSS     163.75
# AAPL     179.37
# AMG      228.02
# dtype: float64

# %%
# Open mean price
stocks_cp.xs(key='open',axis=1,level='Stock Info').mean()
# Out:
# Bank Ticker
# ADSK     64.138877
# AMZN    576.867264
# ANSS     93.536255
# AAPL    109.055429
# AMG     179.206223
# dtype: float64

# %%
# Open min price
stocks_cp.xs(key='open',axis=1,level='Stock Info').min()
# Out:
# Bank Ticker
# ADSK     33.3100
# AMZN    248.9400
# ANSS     71.6200
# AAPL     55.4242
# AMG     116.4600
# dtype: float64

# %%
# High max price
stocks_cp.xs(key='high',axis=1,level='Stock Info').max()
# Out:
# Bank Ticker
# ADSK     131.10
# AMZN    1498.00
# ANSS     164.90
# AAPL     180.10
# AMG      230.63
# dtype: float64

# %%
# High mean price 
stocks_cp.xs(key='high',axis=1,level='Stock Info').mean()
# Out:
# Bank Ticker
# ADSK     64.874703
# AMZN    582.017221
# ANSS     94.360107
# AAPL    109.951118
# AMG     180.924987
# dtype: float64

# %%
# High min price 
stocks_cp.xs(key='high',axis=1,level='Stock Info').min()
# Out:
# Bank Ticker
# ADSK     33.6800
# AMZN    252.9300
# ANSS     71.9500
# AAPL     57.0857
# AMG     120.0700
# dtype: float64

# %%
# Low max price 
stocks_cp.xs(key="low",axis=1,level='Stock Info').max()
# Out:
# Bank Ticker
# ADSK     129.26
# AMZN    1450.04
# ANSS     162.40
# AAPL     178.25
# AMG      227.50
# dtype: float64

# %%
# Low mean price 
stocks_cp.xs(key='low',axis=1,level='Stock Info').mean()
# Out:
# Bank Ticker
# ADSK     63.417575
# AMZN    571.113517
# ANSS     92.745848
# AAPL    108.141589
# AMG     177.340267
# dtype: float64

# %%
# Low min price
stocks_cp.xs(key='low',axis=1,level='Stock Info').min()
# Out:
# Bank Ticker
# ADSK     33.0050
# AMZN    245.7500
# ANSS     70.6600
# AAPL     55.0142
# AMG     115.9700
# dtype: float64

# %% [markdown]
# **Create a new empty DataFrame called returns. This dataframe will contain the returns for each bank's stock. returns are typically defined by:**
#
# $$r_t = \frac{p_t - p_{t-1}}{p_{t-1}} = \frac{p_t}{p_{t-1}} - 1$$

# %%
returns=pd.DataFrame()

# %%
for tick in tickers:
    returns[tick+ "Return"]=stocks_cp[tick]["close"].pct_change()

# %%
returns
# Out:
#       ADSKReturn  AMZNReturn  ANSSReturn  AAPLReturn  AMGReturn
# 0            NaN         NaN         NaN         NaN        NaN
# 1       0.000000   -0.018095    0.000268    0.010422  -0.006009
# 2       0.000514    0.005793    0.013787   -0.025067   0.001237
# 3      -0.006425    0.041631    0.001980   -0.001903   0.004940
# 4       0.000259   -0.000854   -0.005007   -0.000899   0.005940
# ...          ...         ...         ...         ...        ...
# 1254   -0.000432   -0.041967    0.010826    0.002090   0.010670
# 1255   -0.034005    0.028741   -0.019033   -0.043390  -0.023047
# 1256   -0.022035   -0.027938   -0.026639   -0.024984  -0.043681
# 1257    0.031508    0.038014    0.006922    0.041792   0.011671
# 1258   -0.018469   -0.018062   -0.013176   -0.021407  -0.014840
#
# [1259 rows x 5 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(15,7))
sns.heatmap(returns,cmap='rocket')
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(returns[1:],palette="YlGnBu’")

# %%
hm=returns.corr()

# %%
plt.figure(figsize=(15,10))
sns.heatmap(hm,cmap='Greens',annot=True)
# Out:
# <AxesSubplot:>

# %%
returns.columns
# Out:
# Index(['ADSKReturn', 'AMZNReturn', 'ANSSReturn', 'AAPLReturn', 'AMGReturn'], dtype='object')

# %%
returns.corr()['AMZNReturn'].sort_values()
# Out:
# AAPLReturn    0.287659
# ADSKReturn    0.311012
# AMGReturn     0.322904
# ANSSReturn    0.324702
# AMZNReturn    1.000000
# Name: AMZNReturn, dtype: float64

# %%
returns.min()
# Out:
# ADSKReturn   -0.158599
# AMZNReturn   -0.109972
# ANSSReturn   -0.075297
# AAPLReturn   -0.079927
# AMGReturn    -0.115693
# dtype: float64

# %%
returns['AAPLReturn'].min()
# Out:
# -0.07992721520596913

# %%
returns['AMGReturn'].min()
# Out:
# -0.1156931561794936

# %%
returns['ADSKReturn'].min()
# Out:
# -0.1585994613312811

# %%
returns['ANSSReturn'].min()
# Out:
# -0.0752970606629143

# %%
returns['AMZNReturn'].min()
# Out:
# -0.10997245725912508

# %%
# Rt id xmin
returns.idxmin()
# Out:
# ADSKReturn    1211
# AMZNReturn     246
# ANSSReturn      57
# AAPLReturn     243
# AMGReturn      850
# dtype: int64

# %%
# Rt max
returns.max()
# Out:
# ADSKReturn    0.146927
# AMZNReturn    0.141311
# ANSSReturn    0.113853
# AAPLReturn    0.081982
# AMGReturn     0.085331
# dtype: float64

# %%
# Rt id xmax
returns.idxmax()
# Out:
# ADSKReturn    1077
# AMZNReturn     555
# ANSSReturn     120
# AAPLReturn     303
# AMGReturn      306
# dtype: int64

# %%
returns.std()
# Out:
# ADSKReturn    0.018774
# AMZNReturn    0.018235
# ANSSReturn    0.012977
# AAPLReturn    0.014593
# AMGReturn     0.016827
# dtype: float64

# %%
returns.mean()
# Out:
# ADSKReturn    0.001007
# AMZNReturn    0.001508
# ANSSReturn    0.000665
# AAPLReturn    0.000786
# AMGReturn     0.000340
# dtype: float64

# %% [markdown]
# # Create a displot using seaborn of the 2015 returns for Morgan Stanly

# %%
sns.distplot(returns.std()['AAPLReturn'],color='green',bins=40)
# Out:
# C:\Users\DeLL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#
# C:\Users\DeLL\anaconda3\lib\site-packages\seaborn\distributions.py:316: UserWarning:
#
# Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ## Visualization

# %%
#pip install plotly

# %%
#pip install matplotlib

# %%
#pip install cufflinks

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
import plotly
# %matplotlib inline
import cufflinks as cf
import datetime as dt
cf.go_offline()
import plotly.io as pio
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# **Chart show close price of companys**

# %%
stocks_cp.set_index("date")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16796\4188353959.py in <module>
# ----> 1 stocks_cp.set_index("date")
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    6010
#    6011         if missing:
# -> 6012             raise KeyError(f"None of {missing} are in the columns")
#    6013
#    6014         if inplace:
#
# KeyError: "None of ['date'] are in the columns"

# %%
plt.figure(figsize=(12,8))
for tick in tickers:
    stocks_cp[tick]['close'].plot(label=tick,figsize=(12,4))
plt.legend()

# %%
plt.figure(figsize=(12,8))
stocks_cp.xs(key='close',axis=1,level="Stock Info").plot(xlabel='date')
# Out:
# <AxesSubplot:xlabel='date'>

# %%
stocks_cp.xs(key='close',axis=1,level="Stock Info").iplot()
# Out:
# <div>                            <div id="f490bb98-08d1-426a-9f9c-19f69dd2bc4a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# **Chart show open price of companys**

# %%
plt.figure(figsize=(12,8))
for tick in tickers:
    stocks_cp[tick]['open'].plot(label=tick,figsize=(12,4))
plt.legend()

# %%
stocks_cp.xs(key='open',axis=1,level="Stock Info").iplot()
# Out:
# <div>                            <div id="f7dc35b5-0021-4bce-9164-9a450375810c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# # Heat map

# %% [markdown]
# **Close Price**

# %%
plt.figure(figsize=(15,8))
sns.heatmap(stocks_cp.xs(key="close",axis=1,level="Stock Info").corr(),annot=True,cmap="coolwarm")
# Out:
# <AxesSubplot:xlabel='Bank Ticker', ylabel='Bank Ticker'>

# %%
close_corr=stocks_cp.xs(key="close",axis=1,level="Stock Info").corr()
close_corr.iplot(kind='heatmap',colorscale='rdylbu')
# Out:
# <div>                            <div id="e91343e2-3270-49b7-8c2d-440f5512eadf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
plt.figure(figsize=(12,6))
sns.clustermap(stocks_cp.xs(key="close",axis=1,level="Stock Info").corr(),annot=True,cmap="tab10")

# %%
close_corr=stocks_cp.xs(key="close",axis=1,level="Stock Info").corr()
close_corr
# Out:
# Bank Ticker      ADSK      AMZN      ANSS      AAPL       AMG
# Bank Ticker
# ADSK         1.000000  0.896229  0.908165  0.896269 -0.019495
# AMZN         0.896229  1.000000  0.902450  0.819078 -0.270318
# ANSS         0.908165  0.902450  1.000000  0.844482  0.015036
# AAPL         0.896269  0.819078  0.844482  1.000000  0.150510
# AMG         -0.019495 -0.270318  0.015036  0.150510  1.000000

# %%
plt.figure(figsize=(12,7))
sns.heatmap(close_corr,cmap="Greens",annot=True)
# Out:
# <AxesSubplot:xlabel='Bank Ticker', ylabel='Bank Ticker'>

# %% [markdown]
# **Open Price**

# %%
plt.figure(figsize=(15,8))
sns.heatmap(stocks_cp.xs(key="open",axis=1,level="Stock Info").corr(),annot=True,cmap="tab20")
# Out:
# <AxesSubplot:xlabel='Bank Ticker', ylabel='Bank Ticker'>

# %%
close_corr=stocks_cp.xs(key="open",axis=1,level="Stock Info").corr()
close_corr.iplot(kind='heatmap',colorscale='rdylbu')
# Out:
# <div>                            <div id="71b31f76-2af2-46f8-87c3-a8532034dee4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
plt.figure(figsize=(12,6))
sns.clustermap(stocks_cp.xs(key="open",axis=1,level="Stock Info").corr(),annot=True,cmap="rocket")

# %%
close_corr=stocks_cp.xs(key="open",axis=1,level="Stock Info").corr()
close_corr
# Out:
# Bank Ticker      ADSK      AMZN      ANSS      AAPL       AMG
# Bank Ticker
# ADSK         1.000000  0.895942  0.907526  0.895927 -0.020163
# AMZN         0.895942  1.000000  0.901930  0.818154 -0.270304
# ANSS         0.907526  0.901930  1.000000  0.843338  0.014118
# AAPL         0.895927  0.818154  0.843338  1.000000  0.151877
# AMG         -0.020163 -0.270304  0.014118  0.151877  1.000000

# %%
plt.figure(figsize=(12,7))
sns.heatmap(close_corr,cmap="mako",annot=True)
# Out:
# <AxesSubplot:xlabel='Bank Ticker', ylabel='Bank Ticker'>

# %% [markdown]
# **Chart show volume price of companys**

# %%
plt.figure(figsize=(15,8))
sns.heatmap(stocks_cp.xs(key="volume",axis=1,level="Stock Info").corr(),annot=True,cmap="magma")
# Out:
# <AxesSubplot:xlabel='Bank Ticker', ylabel='Bank Ticker'>

# %%
close_corr=stocks_cp.xs(key="volume",axis=1,level="Stock Info").corr()
close_corr.iplot(kind='heatmap',colorscale='rdylbu')
# Out:
# <div>                            <div id="5efee145-2851-4089-b3f5-a2193adc1d33" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
plt.figure(figsize=(12,6))
sns.clustermap(stocks_cp.xs(key="volume",axis=1,level="Stock Info").corr(),annot=True,cmap="vlag")

# %%
close_corr=stocks_cp.xs(key="volume",axis=1,level="Stock Info").corr()
close_corr
# Out:
# Bank Ticker      ADSK      AMZN      ANSS      AAPL       AMG
# Bank Ticker
# ADSK         1.000000  0.060915  0.066746  0.187979  0.055168
# AMZN         0.060915  1.000000  0.156992  0.077036  0.158133
# ANSS         0.066746  0.156992  1.000000 -0.031768  0.078304
# AAPL         0.187979  0.077036 -0.031768  1.000000 -0.006338
# AMG          0.055168  0.158133  0.078304 -0.006338  1.000000

# %%
plt.figure(figsize=(12,7))
sns.heatmap(close_corr,cmap="terrain_r",annot=True)
# Out:
# <AxesSubplot:xlabel='Bank Ticker', ylabel='Bank Ticker'>

# %%
AMZN.iplot(kind="candle")
# Out:
# <div>                            <div id="e484aa9c-b2d4-4938-88b9-7d2a9ca589a3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
ANSS.iplot(kind="candle")
# Out:
# <div>                            <div id="7a1245ce-32c4-44a4-93a0-48ab743bce82" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
AAPL.iplot(kind="candle")
# Out:
# <div>                            <div id="bb10c6d3-cb02-4ce3-a8e1-bfabb4efe15a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
AMG.iplot(kind="candle")
# Out:
# <div>                            <div id="0cd3b9dd-5a94-4ba6-b52c-3e3ce57758fa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
